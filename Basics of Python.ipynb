# %%
# Python Program to check if a number is prime or not
def is_prime(num):
    if num <= 1:  # 0 and 1 are not prime numbers nor composite numbers
        return False
    for i in range(2, int(num**0.5) + 1):   # Required condition
        if num % i == 0:
            return False
    return True
# Input from the user
number = int(input("Enter a number: "))
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# 49 is not a prime number.

# %%
# A Python program to generate two random numbers and asks the users to enter the product of these two numbers. Also, it gives the user feedback whether the answer is correct or not.
import random
def multiply_quiz():  # Random number between 1 and 10
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)
    correct_answer = num1 * num2

    user_answer = int(input(f"What is {num1} multiplied by {num2}? Enter your answer:"))

    if user_answer == correct_answer:
        print("That's Right!")
    else:
        print(f"Wrong! The correct answer is {correct_answer}.")
# Calling the function
multiply_quiz()
# Out:
# Wrong! The correct answer is 10.

# %%
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.
def print_squares_of_odd_numbers():
    print("Squares of odd numbers between 100 and 200 inclusive:")
    for num in range(100, 201):
        if num % 2 != 0:  # Check if the number is odd
            print(f"The square of {num} is {num ** 2}")
print_squares_of_odd_numbers()
# Out:
# Squares of odd numbers between 100 and 200 inclusive:
# The square of 101 is 10201
# The square of 103 is 10609
# The square of 105 is 11025
# The square of 107 is 11449
# The square of 109 is 11881
# The square of 111 is 12321
# The square of 113 is 12769
# The square of 115 is 13225
# The square of 117 is 13689
# The square of 119 is 14161
# The square of 121 is 14641
# The square of 123 is 15129
# The square of 125 is 15625
# The square of 127 is 16129
# The square of 129 is 16641
# The square of 131 is 17161
# The square of 133 is 17689
# The square of 135 is 18225
# The square of 137 is 18769
# The square of 139 is 19321
# The square of 141 is 19881
# The square of 143 is 20449
# The square of 145 is 21025
# The square of 147 is 21609
# The square of 149 is 22201
# The square of 151 is 22801
# The square of 153 is 23409
# The square of 155 is 24025
# The square of 157 is 24649
# The square of 159 is 25281
# The square of 161 is 25921
# The square of 163 is 26569
# ...

# %%
# A Python Program to generate a word count from a given string.
def word_count(input_string):
    words = input_string.split()  # Split the string into separate words
    word_count_dict = {}
    for word in words:
        word = word.lower()  # Convert to lowercase to make the count case-insensitive
        if word in word_count_dict:
            word_count_dict[word] += 1
        else:
            word_count_dict[word] = 1
    return word_count_dict
# Demo usage
input_string = "This is a sample string that contains several words. I repeat, that this string of these words is just a sample."
count_result = word_count(input_string)
print("Word Count:", count_result)
# Out:
# Word Count: {'this': 2, 'is': 2, 'a': 2, 'sample': 1, 'string': 2, 'that': 2, 'contains': 1, 'several': 1, 'words.': 1, 'i': 1, 'repeat,': 1, 'of': 1, 'these': 1, 'words': 1, 'just': 1, 'sample.': 1}

# %%
# A Python program to check if a given string is a palindrome or not.
def is_palindrome(s):
    s = s.replace(" ", "").lower()  # Removes spaces and convert to lowercase
    return s == s[::-1]  # Check if the string is equal to its reverse
# Demo usage
test_string = "A man a plan a canal Panama"
if is_palindrome(test_string):
    print(f'"{test_string}" is a palindrome.')
else:
    print(f'"{test_string}" is not a palindrome.')
# Out:
# "A man a plan a canal Panama" is a palindrome.
